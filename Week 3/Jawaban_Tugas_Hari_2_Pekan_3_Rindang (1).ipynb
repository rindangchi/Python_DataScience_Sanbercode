# %% [markdown]
# <h2>Soal 1:</h2>
#
# Dengan menggunakan data di bawah ini, plot kan data tersebut kemudian custom sehingga memiliki result seperti yang di harapkan :
#
# note: warna terdiri dari warna Hijau, kuning, Biru, dan Merah

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
cos = np.cos(x)
cos3 = np.cos(x)*3
sin = np.sin(x-90)
sin2 = np.sin(x)*2

# %%
# code here

fig, ax = plt.subplots()
fig.set_figheight(8)
fig.set_figwidth(12)

#mengatur line style dan warna garis
ax.plot(x,cos, linestyle='solid', color = 'red', label = 'Cosx')
ax.plot(x,cos3, linestyle='--', color = 'green', label = '3 Cosx')
ax.plot(x,sin, linestyle='-.', color = 'blue', label = 'Sin(x-90)')
ax.plot(x,sin2, linestyle = 'none', marker='x', color = 'yellow', label = '2 Sinx')

#memberikan legend
plt.legend(loc='center')

#mengubah nama axis dan nama gambar
ax.set_xlabel('X-Axis Label')
ax.set_ylabel('Y-Axis Label')
ax.set_title('Grafik Cos Sin')

plt.show()

# %% [markdown]
# Expected Result:
#
# ![alt text](https://drive.google.com/uc?id=1XRcfWyiWLDmriw7s7U4fTn5Gs6s2qf5o)
